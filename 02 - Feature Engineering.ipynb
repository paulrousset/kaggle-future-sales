# %%
import pandas as pd
import numpy as np

from utils import shop_city_mapping

# %% [markdown]
# ---

# %% [markdown]
# # Loading Files

# %% [markdown]
# ---

# %% [markdown]
# ### Train Data

# %%
train_raw = pd.read_csv('data/sales_train.csv')
items = pd.read_csv('data/items_en.csv')
categories = pd.read_csv('data/item_categories_en.csv')
shops = pd.read_csv('data/shops_en.csv')

# %% [markdown]
# ### Test Data

# %%
test = pd.read_csv('data/test.csv')
test.shape
# Out:
# (214200, 3)

# %%
train_raw
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 2935844           1.0
# 2935845           1.0
# 2935846           1.0
# 2935847           1.0
# 2935848           1.0
#
# [2935849 rows x 6 columns]

# %% [markdown]
# ---

# %% [markdown]
# # Cleaning Data

# %% [markdown]
# ---

# %% [markdown]
# ### Shops
#
# We observed that shop 10 & 11 are referring to the same shop. Let's regroup them under shop ID 10

# %%
train_raw.loc[train_raw['shop_id']==11,'shop_id'] = 10

# %% [markdown]
# ### Items
#
# We know that some items sold might be returned and thus recorded as a negative sale <br>
# We should decide later on if and how to deal with that <br>
# At this stage we will only remove the few cases we observed with aggregated negative volume since they are not in the test set

# %%
train_raw.shape
# Out:
# (2935849, 6)

# %%
item_stats = train_raw.groupby('item_id').agg({'item_cnt_day':'sum'})
item_to_remove = item_stats[item_stats['item_cnt_day']<0].index.to_list()
train_raw = train_raw.loc[~train_raw['item_id'].isin(item_to_remove)]

# %%
train_raw.shape
# Out:
# (2935838, 6)

# %% [markdown]
# We also noticed in the EDA that there is one occurence of item with a negative price. Let's fix it.

# %%
train_raw.loc[train_raw['item_price']==-1,'item_price'] = 2499

# %% [markdown]
# ---

# %% [markdown]
# # Grouping data to match prediction scope
#
# We will group data by month - item - shop

# %% [markdown]
# ---

# %%
train_raw.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
train = train_raw.groupby(['date_block_num','item_id','shop_id']).agg({'item_cnt_day':'sum', 'item_price':'mean'}).reset_index()
train.shape
# Out:
# (1609116, 5)

# %%
train.head()
# Out:
#    date_block_num  item_id  shop_id  item_cnt_day  item_price
# 0               0       19       25           1.0        28.0
# 1               0       27        1           1.0      1890.0
# 2               0       27        2           1.0      2499.0
# 3               0       27       10           1.0      1890.0
# 4               0       27       19           1.0      2499.0

# %% [markdown]
# ---

# %% [markdown]
# # Gathering all data

# %% [markdown]
# ---

# %%
train = train.merge(items, on = 'item_id', how = 'left').merge(shops, on='shop_id', how = 'left').merge(categories, on = 'item_category_id', how ='left')
train.shape
# Out:
# (1609116, 12)

# %%
train.head()
# Out:
#    date_block_num  item_id  shop_id  item_cnt_day  item_price  \
# 0               0       19       25           1.0        28.0
# 1               0       27        1           1.0      1890.0
# 2               0       27        2           1.0      2499.0
# 3               0       27       10           1.0      1890.0
# 4               0       27       19           1.0      2499.0
#
#                            item_name  item_category_id  \
# 0          /ЗОЛОТАЯ КОЛЛЕКЦИЯ м/ф-72                40
# 1  007 Legends [PS3, русская версия]                19
# 2  007 Legends [PS3, русская версия]                19
# 3  007 Legends [PS3, русская версия]                19
# 4  007 Legends [PS3, русская версия]                19
#
#                          item_name_en                      shop_name  \
# 0             /Gold collection M/F-72            Москва ТРК "Атриум"
# 1  007 legends [PS3, Russian version]  !Якутск ТЦ "Центральный" фран
# 2  007 legends [PS3, Russian version]               Адыгея ТЦ "Мега"
# 3  007 legends [PS3, Russian version]     Жуковский ул. Чкалова 39м?
# 4  007 legends [PS3, Russian version]          Курск ТЦ "Пушкинский"
#
#                 shop_name_en item_category_name item_category_name_en
# 0            Moscow - Atrium         Кино - DVD           Movie - DVD
# 1     Yakutsk - Central Mall         Игры - PS3            Games- PS3
# 2         Adygea - Mega Mall         Игры - PS3            Games- PS3
# 3  Moscow - Jukovski Airport         Игры - PS3            Games- PS3
# 4    Kursk - Pushkinsky Mall         Игры - PS3            Games- PS3

# %% [markdown]
# ---

# %% [markdown]
# # Feature Engineering
#
# There are ways to approach this problem:
# - We could approach it as pure time-series issue where and use a statistical model or multiple (let's say at item category level) to forecast sales volume globally using trends and seasonality. And then figure a way to distribute the result over shops and items.
# - A second approach is to use a supervised machine-learning approach where our target is the current month volume and features include item, shop, category etc... It will not capture trends as well as the first approach but it will provide results with the required granularity
#
# We will start with the second approach

# %% [markdown]
# ---

# %% [markdown]
# ###  Item Recency
#
# Number of months since first observed sale for an item

# %%
train = train.sort_values(by=['item_id','date_block_num'])
item_first_month = train.drop_duplicates('item_id', keep = 'first')[['item_id','date_block_num']]
item_first_month.columns = ['item_id','item_first_month']
train = train.merge(item_first_month, on = 'item_id', how = 'left')
train['item_Recency'] = train['date_block_num'] - train['item_first_month']

# %% [markdown]
# ###  Month of the year
# We know there is a seasonality so we can capture it with month variable

# %%
train['month'] = train['date_block_num'].mod(12)+1
train.head()
# Out:
#    date_block_num  item_id  shop_id  item_cnt_day  item_price  \
# 0              20        0       54           1.0        58.0
# 1              15        1       55           2.0      4490.0
# 2              18        1       55           1.0      4490.0
# 3              19        1       55           1.0      4490.0
# 4              20        1       55           1.0      4490.0
#
#                                            item_name  item_category_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D                40
# 1  !ABBYY FineReader 12 Professional Edition Full...                76
# 2  !ABBYY FineReader 12 Professional Edition Full...                76
# 3  !ABBYY FineReader 12 Professional Edition Full...                76
# 4  !ABBYY FineReader 12 Professional Edition Full...                76
#
#                                         item_name_en  \
# 0              !In the power of obsession (plast.) D
# 1  ! Abbyy Finereader 12 Professional Edition Ful...
# 2  ! Abbyy Finereader 12 Professional Edition Ful...
# 3  ! Abbyy Finereader 12 Professional Edition Ful...
# 4  ! Abbyy Finereader 12 Professional Edition Ful...
#
#                   shop_name                            shop_name_en  \
# 0           Химки ТЦ "Мега"                    Moscow - Mega Khimki
# 1  Цифровой склад 1С-Онлайн  Internet - Digital Warehouse 1C Online
# 2  Цифровой склад 1С-Онлайн  Internet - Digital Warehouse 1C Online
# 3  Цифровой склад 1С-Онлайн  Internet - Digital Warehouse 1C Online
# 4  Цифровой склад 1С-Онлайн  Internet - Digital Warehouse 1C Online
#
#                      item_category_name  \
# 0                            Кино - DVD
# 1  Программы - Для дома и офиса (Цифра)
# 2  Программы - Для дома и офиса (Цифра)
# 3  Программы - Для дома и офиса (Цифра)
# 4  Программы - Для дома и офиса (Цифра)
#
#                      item_category_name_en  item_first_month  item_Recency  \
# 0                              Movie - DVD                20             0
# 1  Programs - For Home and Office (Number)                15             0
# 2  Programs - For Home and Office (Number)                15             3
# 3  Programs - For Home and Office (Number)                15             4
# 4  Programs - For Home and Office (Number)                15             5
#
#    month
# 0      9
# 1      4
# 2      7
# 3      8
# 4      9

# %% [markdown]
# ###  Shop City

# %%
train['shop_city'] = train['shop_name_en'].str.extract('(.*) -')
train.head()
# Out:
#    date_block_num  item_id  shop_id  item_cnt_day  item_price  \
# 0              20        0       54           1.0        58.0
# 1              15        1       55           2.0      4490.0
# 2              18        1       55           1.0      4490.0
# 3              19        1       55           1.0      4490.0
# 4              20        1       55           1.0      4490.0
#
#                                            item_name  item_category_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D                40
# 1  !ABBYY FineReader 12 Professional Edition Full...                76
# 2  !ABBYY FineReader 12 Professional Edition Full...                76
# 3  !ABBYY FineReader 12 Professional Edition Full...                76
# 4  !ABBYY FineReader 12 Professional Edition Full...                76
#
#                                         item_name_en  \
# 0              !In the power of obsession (plast.) D
# 1  ! Abbyy Finereader 12 Professional Edition Ful...
# 2  ! Abbyy Finereader 12 Professional Edition Ful...
# 3  ! Abbyy Finereader 12 Professional Edition Ful...
# 4  ! Abbyy Finereader 12 Professional Edition Ful...
#
#                   shop_name                            shop_name_en  \
# 0           Химки ТЦ "Мега"                    Moscow - Mega Khimki
# 1  Цифровой склад 1С-Онлайн  Internet - Digital Warehouse 1C Online
# 2  Цифровой склад 1С-Онлайн  Internet - Digital Warehouse 1C Online
# 3  Цифровой склад 1С-Онлайн  Internet - Digital Warehouse 1C Online
# 4  Цифровой склад 1С-Онлайн  Internet - Digital Warehouse 1C Online
#
#                      item_category_name  \
# 0                            Кино - DVD
# 1  Программы - Для дома и офиса (Цифра)
# 2  Программы - Для дома и офиса (Цифра)
# 3  Программы - Для дома и офиса (Цифра)
# 4  Программы - Для дома и офиса (Цифра)
#
#                      item_category_name_en  item_first_month  item_Recency  \
# 0                              Movie - DVD                20             0
# 1  Programs - For Home and Office (Number)                15             0
# 2  Programs - For Home and Office (Number)                15             3
# 3  Programs - For Home and Office (Number)                15             4
# 4  Programs - For Home and Office (Number)                15             5
#
#    month shop_city
# 0      9    Moscow
# 1      4  Internet
# 2      7  Internet
# 3      8  Internet
# 4      9  Internet

# %% [markdown]
# ###  Window Data
#
# We want to capture information of the preceeding month

# %%
def get_info_previous_month(df):
    data = df.sort_values(by = ['item_id','shop_id','date_block_num'])
    data['item_id_prev'] = data['item_id'].shift(1)
    data['has_previous_data'] = (data['item_id_prev'] == data['item_id']).astype(int)
    data.loc[data['has_previous_data'] == 1, 'item_cnt_day_prev'] = data['item_cnt_day']  
    data.loc[data['has_previous_data'] == 1, 'item_price_prev'] = data['item_price']
    data.loc[data['has_previous_data'] == 0, 'item_cnt_day_prev'] = 0  
    data.loc[data['has_previous_data'] == 0, 'item_price_prev'] = 0
    return data

# %%
train =  get_info_previous_month(train)
train.head()
# Out:
#    date_block_num  item_id  shop_id  item_cnt_day  item_price  \
# 0              20        0       54           1.0        58.0
# 1              15        1       55           2.0      4490.0
# 2              18        1       55           1.0      4490.0
# 3              19        1       55           1.0      4490.0
# 4              20        1       55           1.0      4490.0
#
#                                            item_name  item_category_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D                40
# 1  !ABBYY FineReader 12 Professional Edition Full...                76
# 2  !ABBYY FineReader 12 Professional Edition Full...                76
# 3  !ABBYY FineReader 12 Professional Edition Full...                76
# 4  !ABBYY FineReader 12 Professional Edition Full...                76
#
#                                         item_name_en  \
# 0              !In the power of obsession (plast.) D
# 1  ! Abbyy Finereader 12 Professional Edition Ful...
# 2  ! Abbyy Finereader 12 Professional Edition Ful...
# 3  ! Abbyy Finereader 12 Professional Edition Ful...
# 4  ! Abbyy Finereader 12 Professional Edition Ful...
#
#                   shop_name                            shop_name_en  \
# 0           Химки ТЦ "Мега"                    Moscow - Mega Khimki
# 1  Цифровой склад 1С-Онлайн  Internet - Digital Warehouse 1C Online
# 2  Цифровой склад 1С-Онлайн  Internet - Digital Warehouse 1C Online
# 3  Цифровой склад 1С-Онлайн  Internet - Digital Warehouse 1C Online
# 4  Цифровой склад 1С-Онлайн  Internet - Digital Warehouse 1C Online
#
#                      item_category_name  \
# 0                            Кино - DVD
# 1  Программы - Для дома и офиса (Цифра)
# 2  Программы - Для дома и офиса (Цифра)
# 3  Программы - Для дома и офиса (Цифра)
# 4  Программы - Для дома и офиса (Цифра)
#
#                      item_category_name_en  item_first_month  item_Recency  \
# 0                              Movie - DVD                20             0
# 1  Programs - For Home and Office (Number)                15             0
# 2  Programs - For Home and Office (Number)                15             3
# 3  Programs - For Home and Office (Number)                15             4
# 4  Programs - For Home and Office (Number)                15             5
#
#    month shop_city  item_id_prev  has_previous_data  item_cnt_day_prev  \
# 0      9    Moscow           NaN                  0                0.0
# 1      4  Internet           0.0                  0                0.0
# 2      7  Internet           1.0                  1                1.0
# 3      8  Internet           1.0                  1                1.0
# 4      9  Internet           1.0                  1                1.0
#
#    item_price_prev
# 0              0.0
# 1              0.0
# 2           4490.0
# 3           4490.0
# 4           4490.0

# %% [markdown]
# ###  Encoding
#
# - We will need to encode the city variable
# - Also, we have three id type variables which are categorical (item_id, shop_id and item_category_id) -> These may need encoding as well, depending on the model chosen, as they could be confused with ordinal data.

# %% [raw]
# import random
#
# shop_city_mapping = {}
# cities = train['shop_city'].unique()
# random.shuffle(cities)
#
# for city, code in zip(cities, range(1, len(cities)+1)):
#     shop_city_mapping[city] = code
#
# shop_city_mapping

# %%
train['city_code'] = train['shop_city'].map(shop_city_mapping)
train.head()
# Out:
#    date_block_num  item_id  shop_id  item_cnt_day  item_price  \
# 0              20        0       54           1.0        58.0
# 1              15        1       55           2.0      4490.0
# 2              18        1       55           1.0      4490.0
# 3              19        1       55           1.0      4490.0
# 4              20        1       55           1.0      4490.0
#
#                                            item_name  item_category_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D                40
# 1  !ABBYY FineReader 12 Professional Edition Full...                76
# 2  !ABBYY FineReader 12 Professional Edition Full...                76
# 3  !ABBYY FineReader 12 Professional Edition Full...                76
# 4  !ABBYY FineReader 12 Professional Edition Full...                76
#
#                                         item_name_en  \
# 0              !In the power of obsession (plast.) D
# 1  ! Abbyy Finereader 12 Professional Edition Ful...
# 2  ! Abbyy Finereader 12 Professional Edition Ful...
# 3  ! Abbyy Finereader 12 Professional Edition Ful...
# 4  ! Abbyy Finereader 12 Professional Edition Ful...
#
#                   shop_name                            shop_name_en  ...  \
# 0           Химки ТЦ "Мега"                    Moscow - Mega Khimki  ...
# 1  Цифровой склад 1С-Онлайн  Internet - Digital Warehouse 1C Online  ...
# 2  Цифровой склад 1С-Онлайн  Internet - Digital Warehouse 1C Online  ...
# 3  Цифровой склад 1С-Онлайн  Internet - Digital Warehouse 1C Online  ...
# 4  Цифровой склад 1С-Онлайн  Internet - Digital Warehouse 1C Online  ...
#
#                      item_category_name_en item_first_month  item_Recency  \
# 0                              Movie - DVD               20             0
# 1  Programs - For Home and Office (Number)               15             0
# 2  Programs - For Home and Office (Number)               15             3
# 3  Programs - For Home and Office (Number)               15             4
# 4  Programs - For Home and Office (Number)               15             5
#
#    month  shop_city item_id_prev  has_previous_data  item_cnt_day_prev  \
# 0      9     Moscow          NaN                  0                0.0
# 1      4   Internet          0.0                  0                0.0
# 2      7   Internet          1.0                  1                1.0
# 3      8   Internet          1.0                  1                1.0
# 4      9   Internet          1.0                  1                1.0
#
#    item_price_prev  city_code
# 0              0.0          1
# 1              0.0          5
# 2           4490.0          5
# 3           4490.0          5
# 4           4490.0          5
#
# [5 rows x 21 columns]

# %% [markdown]
# ###  Filtering
#
# - Removing unneeded variables

# %%
col = ['date_block_num','item_id','shop_id','item_cnt_day','item_price','item_category_id','item_Recency','month','item_cnt_day_prev','item_price_prev','city_code']
train = train[col]

# %%
train.head()
# Out:
#    date_block_num  item_id  shop_id  item_cnt_day  item_price  \
# 0              20        0       54           1.0        58.0
# 1              15        1       55           2.0      4490.0
# 2              18        1       55           1.0      4490.0
# 3              19        1       55           1.0      4490.0
# 4              20        1       55           1.0      4490.0
#
#    item_category_id  item_Recency  month  item_cnt_day_prev  item_price_prev  \
# 0                40             0      9                0.0              0.0
# 1                76             0      4                0.0              0.0
# 2                76             3      7                1.0           4490.0
# 3                76             4      8                1.0           4490.0
# 4                76             5      9                1.0           4490.0
#
#    city_code
# 0          1
# 1          5
# 2          5
# 3          5
# 4          5

# %% [markdown]
# ###  Exporting New Train Set
#
# - Removing unneeded variables

# %%
train.to_csv("data/train_processed.csv", index=False)
